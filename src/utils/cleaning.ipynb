# %%
# !pip install Pillow
# Out:
# Collecting Pillow
#   Using cached pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Using cached pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
# Installing collected packages: Pillow
# Successfully installed Pillow-11.2.1

# %%
from pathlib import Path
from PIL import Image, UnidentifiedImageError

def clean_invalid_images(dataset_path):
    """
    Menghapus file non-gambar dan gambar yang rusak dari direktori dataset.

    Args:
        dataset_path (str): Path ke direktori dataset.
    """
    img_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".gif"]
    dataset_path = Path(dataset_path)
    count_removed = 0

    for img_path in dataset_path.rglob("*.*"):
        # Hapus file dengan ekstensi bukan gambar
        if img_path.suffix.lower() not in img_extensions:
            print(f"❌ Bukan gambar: {img_path}")
            img_path.unlink()  # Hapus file
            count_removed += 1
        else:
            # Coba buka gambar, jika gagal berarti rusak
            try:
                with Image.open(img_path) as img:
                    img.verify()  # Validasi gambar tanpa loading penuh
            except (UnidentifiedImageError, OSError):
                print(f"⚠️ Rusak: {img_path}")
                img_path.unlink()
                count_removed += 1

    print(f"\n✅ Selesai! {count_removed} file dihapus.")

folder_dataset = "Batik Nitik Sarimbit 120"
clean_invalid_images(folder_dataset)
# Out:
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/48 Sekar Jeruk B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/34 Kuncup Kanthil B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/52 Sekar Blimbing B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/27 Kawung Nitik B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/1 Sekar Kemuning A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/60 Sekar Gambir A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/10 Sekar Ketongkeng A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/56 Sekar Kepel B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/13 Sekar Menur B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/37 Manggar A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/26 Sekar Nangka A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/14 Sekar Tebu A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/9 Sekar Gudhe B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/53 Sekar Pijetan B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/42 Gedhangan B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/18 Sekar Dhuku B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/19 Sekar Jagung B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/36 Sekar Sawo B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/54 Sari Mulat B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/42 Gedhangan A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/46 Sekar Lintang B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/17 Worawari Rumpuk B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/6 Arumdalu B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/50 Tanjung Gunung A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/44 Klampok Arum B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/32 Cinde Wilis B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/31 Krawitan  B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/39 Sritaman B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/7 Sekar Srigadhing B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/25 Sekar Soka A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/45 Sekar Jali B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/1 Sekar Kemuning B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/40 Sekar Mundhu B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/51 Sekar Kenikir B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/10 Sekar Ketongkeng B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/2 Sekar Liring B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/52 Sekar Blimbing A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/3 Sekar Duren A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/31 Krawitan  A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/29 Sekar Pudhak A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/57 Truntum Kurung B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/24 Sekar Srengenge A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/50 Tanjung Gunung B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/47 Sekar Kenanga B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/4 Sekar Gayam B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/3 Sekar Duren B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/41 Sekar Andhong A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/59 Rengganis B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/40 Sekar Mundhu A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/43 Sekar Pala B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/11 Brendhi A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/59 Rengganis A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/20 Jayakirana A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/23 Sekar Keben A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/55 Sekar Mrica A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/46 Sekar Lintang A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/7 Sekar Srigadhing A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/58 Jayakusuma B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/38 Sekar Cengkeh A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/56 Sekar Kepel A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/15 Sekar Manggis B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/30 Sekar Dlima B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/55 Sekar Mrica B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/2 Sekar Liring A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/38 Sekar Cengkeh B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/9 Sekar Gudhe A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/15 Sekar Manggis A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/21 Mawur A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/21 Mawur B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/25 Sekar Soka B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/22 Sekar Tanjung B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/60 Sekar Gambir B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/43 Sekar Pala A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/37 Manggar B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/16 Sekar Randhu A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/29 Sekar Pudhak B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/49 Sekar Mindi A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/16 Sekar Randhu B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/54 Sari Mulat A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/49 Sekar Mindi B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/20 Jayakirana B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/18 Sekar Dhuku A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/47 Sekar Kenanga A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/17 Worawari Rumpuk A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/35 Sekar Dangan A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/23 Sekar Keben B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/48 Sekar Jeruk A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/45 Sekar Jali A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/35 Sekar Dangan B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/26 Sekar Nangka B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/22 Sekar Tanjung A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/14 Sekar Tebu B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/8 Kemukus B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/34 Kuncup Kanthil A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/30 Sekar Dlima A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/58 Jayakusuma A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/28 Sekar Kenthang B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/33 Sekar Mlathi B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/4 Sekar Gayam A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/11 Brendhi B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/51 Sekar Kenikir A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/24 Sekar Srengenge B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/27 Kawung Nitik A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/13 Sekar Menur A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/12 Cakar Ayam A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/12 Cakar Ayam B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/5 Sekar Pacar A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/28 Sekar Kenthang A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/5 Sekar Pacar B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/19 Sekar Jagung A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/8 Kemukus A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/57 Truntum Kurung A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/53 Sekar Pijetan A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/41 Sekar Andhong B.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/44 Klampok Arum A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/6 Arumdalu A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/33 Sekar Mlathi A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/32 Cinde Wilis A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/39 Sritaman A.jpg:Zone.Identifier
# ❌ Bukan gambar: Batik Nitik Sarimbit 120/36 Sekar Sawo A.jpg:Zone.Identifier
#
# ✅ Selesai! 120 file dihapus.

# %%
from pathlib import Path
import shutil
import re

def get_class_name(file_name: str) -> str:
    """
    Mengambil nama kelas dari nama file.
    Contoh: '1 Arumdalu B 2_rotate_90.jpg' → 'Arumdalu'
    """
    # Hapus ekstensi
    name = file_name.rsplit('.', 1)[0]

    # Hapus angka label di awal dan informasi rotasi di akhir
    name = re.sub(r'^\d+\s+', '', name)                    # hapus angka awal dan spasi
    name = re.sub(r'\s+\d+(_rotate_\d+)?$', '', name)      # hapus angka urut dan rotasi

    # Hapus huruf tambahan di akhir nama kelas (misal A, B)
    name = re.sub(r'\s+[A-B]$', '', name)                  # hapus ' A' atau ' B'

    return name.strip()

def group_images_by_classname(source_folder, target_folder):
    source_folder = Path(source_folder)
    target_folder = Path(target_folder)
    target_folder.mkdir(parents=True, exist_ok=True)

    for img_path in source_folder.glob("*.jpg"):
        class_name = get_class_name(img_path.name)
        class_folder = target_folder / class_name
        class_folder.mkdir(exist_ok=True)
        
        # Cegah overwrite
        destination = class_folder / img_path.name
        if destination.exists():
            base = img_path.stem
            ext = img_path.suffix
            i = 1
            while (class_folder / f"{base}_{i}{ext}").exists():
                i += 1
            destination = class_folder / f"{base}_{i}{ext}"
        
        shutil.copy(img_path, destination)

    print("✅ Semua gambar berhasil digabungkan ke dalam folder kelas utama.")

# Contoh penggunaan:
group_images_by_classname("Batik Nitik 960", "Batik Nitik Grouped")
# Out:
# ✅ Semua gambar berhasil digabungkan ke dalam folder kelas utama.
